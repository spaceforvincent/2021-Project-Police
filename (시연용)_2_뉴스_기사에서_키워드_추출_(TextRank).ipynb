# %% [markdown]
# # 최혁주
# ## 뉴스 기사에서 키워드 추출
# - https://bab2min.tistory.com/552 textrank 알고리즘 소개
# - https://bab2min.tistory.com/570 textrank 구현코드

# %%
#뉴스가 담긴 엑셀 불러오기
news = pd.read_csv('2021-08-22-01-59-45-아시아경제.csv')
news.head()
# Out:
#         뉴스등록번호  ...                                              뉴스URL
# 0  19193190616  ...  https://www.asiae.co.kr/article/20210821191931...
# 1  18362968132  ...  https://www.asiae.co.kr/article/20210821183629...
# 2  17502046495  ...  https://www.asiae.co.kr/article/20210821175020...
# 3  17132324488  ...  https://www.asiae.co.kr/article/20210821171323...
# 4  14524759946  ...  https://www.asiae.co.kr/article/20210821145247...
#
# [5 rows x 5 columns]

# %%
data2 = news['뉴스내용'].tolist() #엑셀 파일 중 full본문 칸이 비어있지 않은 로우들 가져와서 리스트로 만듬
data2[:5]
# Out:
# ['[최근 창원시 가음정동에 차려진 선별진료소에서 시민들이 검사받고 있다., [아시아경제 영남취재본부 김용우 기자] 남창원농협 농수산유통센터발(發) 코로나19 20대 확진자 1명이 숨졌다., 경남도는 21일 오전 10시 기준 코로나19 확진자 2명이 사망했다고 밝혔다.\t, 이 가운데 1명은 20대 남성으로 확인됐으며, 기저질환이 있는 것으로 조사됐다., 이 남성은 앞서 가족이 남창원농협 마트에 방문 후 확진된 것으로 확인된 뒤 검사를 받고, 지난 12일 확진판정을 받았다., 또 다른 사망자 1명은 80대 여성으로 김해 요양병원 관련 확진자이다.\t, 이 요양병원 관련 확진자 중 사망자는 모두 4명으로 늘었으며, 모두 백신접종을 마친 ‘돌파감염’으로 알려졌다., 21일 오전 기준 경남에선 코로나19 확진자 5명이 발생했다. 창원 3명, 의령 2명이다., 감염경로는 도내 확진자 접촉자 2명이며, 의령 사업장 관련 2명, 감염경로 조사 중인 1명 등이다., 21일 오전 10시 현재 도내 코로나19 누적확진자는 9284명(입원 1203, 퇴원 8056, 사망 25)이다., &lt;ⓒ경제를 보는 눈, 세계를 보는 창 아시아경제(www.asiae.co.kr) 무단전재 배포금지&gt;]',
#  '[[이미지출처=연합뉴스], [아시아경제 오현길 기자] 21일 전국에 강풍을 동반한 많은 비가 쏟아져 아파트 유리창이 깨져 주민이 다치거나 옹벽이 무너지는 등 피해가 잇따랐다., 이날 각 지역 소방당국 등에 따르면 오전 11시 21분께 부산시 사상구 모라동 한 아파트 21층에서 강풍에 베란다 창문이 깨지면서 A(52)씨가 다쳐 병원 치료를 받았다.\t, 낮 12시 27분께 금정구 부곡동 온천천에서는 갑자기 불어난 하천 물에 고립된 B(68)씨가 119구조대에 구조되기도 했다., 부산에서는 지하차도 등 17곳에서 교통이 통제됐고 도로 43곳이 침수됐다., 충남 태안군 남면 몽산포자동차야영장에서는 오전 9시 37분께 강풍을 동반한 비로 소나무 1그루가 쓰러지며 8살·10살 여자 어린이들이 있던 텐트를 덮쳤다. 두 아이는 머리 등을 다쳐 인근 병원에서 치료를 받았다.\t, 충
졌다. 폭우로 야외에 설치한 선별진료소 일대가 운영을 중단하기도 했다. 김해시는 진영공설운동장에 설치한 임시 선별검사소 운영을 이날 오후 1시부터 중단했다., 호우경보가 내려진 경남에 많은 비가 쏟아지면서 도로가 침수됐다. [사진=경남소방본부 제공], 호우경보가 내려진 김해 진영읍에 많은 비가 쏟아지면서 운동장 상당 부분이 침수됐기 때문이다. 시는 진단검사를 받으러 오는 시민들이 불편을 겪을 것으로 보고 비가 그치고 물이 빠지는 대로 이르면 22일 운영을 재개하기로 했다. 김해시보건소 등 김해 시내 나머지 임시 선별검사소 8곳가량은 정상 운영한다., 현재 경남에는 창원·김해·양산 등 8개 시·군에 호우경보가, 진주·산청·하동 등 7개 시·군에 호우주의보가 발령 중이다., &lt;ⓒ경제를 보는 눈, 세계를 보는 창 아시아경제(www.asiae.co.kr) 무단전재 배포금지&gt;]',
#  '[더불어민주당 대선 예비후보인 이재명 경기도지사 [이미지출처=연합뉴스], [아시아경제 정동훈 기자] 더불어민주당 대선 예비 후보인 이재명 경기지사가 지난 6월 경기 이천 쿠팡 물류센터 화재 당시 맛 칼럼니스트 황교익씨와 유튜브 방송을 촬영한 것에 대해 사과했다., 이 지사는 21일 페이스북에서 "저의 판단과 국민의 눈높이에 미치지 못했음을 인정하고 사과 말씀을 드린다"며 "당시 경남 창원에서 실시간 상황 보고를 받고 대응 조치 중 밤늦게 현장 지휘가 필요하다고 판단, 다음날 고성군 일정을 취소하고 새벽 1시반경 사고 현장을 찾았다"고 설명했다.\t, 그러면서 "나름 최선을 다했다고 생각했었지만, 모든 일정을 취소하고 더 빨리 현장에 갔어야 마땅했다는 지적이 옳다"고 자세를 낮췄다., 이 지사는 "앞으로 권한과 책임을 맡긴 경기도민을 더 존중하며 더 낮은 자세로 더 상실하게 섬기겠다"고 덧붙였다. , &lt;ⓒ경제를 보는 눈, 세계를 보는 창 아시아경제(www.asiae.co.kr) 무단전재 배포금지&gt;]']

# %%
#키워드 추출
#window : 문맥으로 사용할 단어의 개수. 기본값 5로 주면 특정 단어의 좌우 5개씩, 총 10개 단어를 문맥으로 사용합니다.
#coef : 동시출현 빈도를 weight에 반영하는 비율입니다. 기본값은 1.0로, 동시출현 빈도를 weight에 전부 반영합니다. 0.0일 경우 빈도를 반영하지 않고 모든 간선의 weight을 1로 동일하게 간주합니다.
#threshold: 문서 요약시 관련있는 문장으로 여길 최소 유사도값. 기본값은 0.005이고, 이 값보다 작은 유사도를 가지는 문장쌍은 관련없는문장으로 처리합니다.
#키워드 추출시에는 load로 문장을 읽어들이고, extract로 키워드를 추출합니다.

for i in range(0,len(data2)):
  tr = TextRank(window=5, coef=1)
  print('Load...')
  stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV'), ('없', 'VV') ])
  tr.load(RawTagger(data2[i]), lambda w: w not in stopword and (w[1] in ('NNG', 'NNP', 'VV', 'VA')))
  print('Build...')
  tr.build() #단어연관성분석
  tr.extract(0.2) #추출비율

# %%
#기사별로 담긴 키워드 확인
keywordlist[:5]
# Out:
# [['아시아 경제', '병원 관련', '코로나 19', '검사 받', '도내 코로나', '관련 확진', '19 확진', '도내 확진'],
#  ['소방 당국', '아시아 경제', '건물 지하'],
#  ['아시아 경제',
#   '배수 장',
#   '길 공단',
#   '굴 다리',
#   '도로 침수',
#   '시장 굴',
#   '장 굴',
#   '공장 일부',
#   '호우 특보',
#   '시장 지하차도',
#   '경남 소방본부',
#   '비와 강풍',
#   '이날 오전',
#   '피해 여성',
#   '이날 오후',
#   '부산 소방본부',
#   '특보 지역',
#   '비 피해'],
#  ['선별 검사소', '임시 선별', '소방 당국', '운동장 상당', '호우 경보', '검사소 운영', '경남 소방본부'],
#  ['센터 화재', '대선 예비', '아시아 경제', '더불어민주당 대선', '화재 당시', '이재명 경기', '경기 지사']]

# %%
#데이터프레임 만들기
df = pd.DataFrame(data2)
df
# Out:
#                                                  기사내용                                            keyword
# 0   [최근 창원시 가음정동에 차려진 선별진료소에서 시민들이 검사받고 있다., [아시아경...  [아시아 경제, 병원 관련, 코로나 19, 검사 받, 도내 코로나, 관련 확진, 1...
# 1   [[이미지출처=연합뉴스], [아시아경제 오현길 기자] 21일 전국에 강풍을 동반한 ...                             [소방 당국, 아시아 경제, 건물 지하]
# 2   [아슬아슬한 공장 건물. 많은 비와 강풍이 몰아친 21일 오후 1시 47분께 경남 ...  [아시아 경제, 배수 장, 길 공단, 굴 다리, 도로 침수, 시장 굴, 장 굴, 공...
# 3   [경남 양산 옹벽 붕괴 현장. [사진=경남소방본부 제공], [아시아경제 영남취재본부...  [선별 검사소, 임시 선별, 소방 당국, 운동장 상당, 호우 경보, 검사소 운영, ...
# 4   [더불어민주당 대선 예비후보인 이재명 경기도지사 [이미지출처=연합뉴스], [아시아경...  [센터 화재, 대선 예비, 아시아 경제, 더불어민주당 대선, 화재 당시, 이재명 경...
# ..                                                ...                                                ...
# 63  [여름 휴가철인 2일 서울 서초구 잠원IC 인근 경부고속도로 하행선에서 차량들이 줄...  [방식 개선, 앞 차, 운영 방식, 개선 필요, 운영 구간, 운영 필요, 추월 차선...
# 64  [[아시아경제 영남취재본부 박새얀 기자] 경남도는 11일 오후 5시 이후 도내에 코...                                    [아시아 경제, 도내 확진]
# 65  [성장현 용산구청장, [아시아경제 박종일 기자] “지난 11년간 열심히 보물찾기를 ...  [취임 이후, 아시아 경제, 공원 조성, 업무 지구, 향후 국제, 국제 업무, 기회...
# 66  [사진=윤석열 전 검찰총장 인스타그램 캡처, [아시아경제 김소영 기자] 곽상도 국민...  [아시아 경제, 매일신문 유튜브, 과거 발언, 경남 기자, 대통령 만들, 이준석 대...
# 67  [경남 창원시가 상남공원의 명칭을 배중세 애국지사의 호(號)를 담은 상남단정공원으로...  [아시아 경제, 성산구 상남동, 배 중세, 중세 애국지사, 창원시 의회, 상남 단정...
#
# [68 rows x 2 columns]

# %%
df.to_csv('키워드도출결과.csv',index=False)
